# %%
#import necessary libraries
import pandas as pd
import os

# %%
# Mount Google Drive to access files if necessary
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define the folder name and file name
folder_name = "Ersilia"
file_name = "pubchem.csv"

# Define the full path to the file
file_path = os.path.join("/content/drive/MyDrive", folder_name, file_name)

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the first 5 rows in DataFrame
print(df.head())
# Out:
#     cid                     cmpdname  \
# 0     1              Acetylcarnitine
# 1     4           1-Aminopropan-2-ol
# 2     6  1-Chloro-2,4-dinitrobenzene
# 3    11           1,2-Dichloroethane
# 4    12  1,2,3,5-Tetrahydroxybenzene
#
#                                          cmpdsynonym      mw          mf  \
# 0  Acetyl-DL-carnitine|acetylcarnitine|DL-Acetylc...  203.24    C9H17NO4
# 1  1-Aminopropan-2-ol|78-96-6|1-AMINO-2-PROPANOL|...   75.11      C3H9NO
# 2  1-chloro-2,4-dinitrobenzene|2,4-Dinitrochlorob...  202.55  C6H3ClN2O4
# 3  1,2-dichloroethane|Ethylene dichloride|107-06-...   98.96     C2H4Cl2
# 4  1,2,3,5-Benzenetetrol|1,2,3,5-tetrahydroxybenz...  142.11      C6H6O4
#
#    polararea  complexity  xlogp  heavycnt  hbonddonor  ...  gpfamilycnt  \
# 0       66.4       214.0    0.4        14           0  ...         1232
# 1       46.2        22.9   -1.0         5           2  ...        31266
# 2       91.6       224.0    2.3        13           0  ...         4796
# 3        0.0         6.0    1.5         4           0  ...        25937
# 4       80.9       104.0    0.8        10           4  ...          166
#
#    neighbortype          meshheadings  \
# 0         2D+3D       Acetylcarnitine
# 1         2D+3D                   NaN
# 2         2D+3D  Dinitrochlorobenzene
# 3         2D+3D                   NaN
# 4         2D+3D                   NaN
#
#                                            annothits annothitcnt  \
# 0  Chemical and Physical Properties|Classificatio...          10
# 1  Biological Test Results|Chemical and Physical ...          14
# 2  Biological Test Results|Chemical and Physical ...          14
# 3  Agrochemical Information|Biological Test Resul...          17
# 4  Classification|Literature|Patents|Pharmacology...           7
#
#                                                 aids  cidcdate  \
# 0                                                NaN  20050623
# 1  155|157|161|165|167|175|1188|23443|158688|6516...  20050326
# 2  155|157|161|165|167|175|179|192|220|300|302|11...  20050326
# 3  421|426|427|433|434|435|445|530|540|541|542|54...  20040916
# 4                                                NaN  20040916
#
#                                           sidsrcname  \
# 0  3WAY PHARM INC|A2B Chem|AA BLOCKS|AbaChemScene...
# 1  001Chemical|3B Scientific (Wuhan) Corp|3WAY PH...
# 2  3B Scientific (Wuhan) Corp|3WAY PHARM INC|A&J ...
# 3  001Chemical|1st Scientific|3B Scientific (Wuha...
# 4  A2B Chem|AA BLOCKS|AAA Chemistry|ABI Chem|AHH ...
#
#                                              depcatg  \
# 0  Chemical Vendors|Curation Efforts|Governmental...
# 1  Chemical Vendors|Curation Efforts|Governmental...
# 2  Chemical Vendors|Curation Efforts|Governmental...
# 3  Chemical Vendors|Curation Efforts|Governmental...
# 4  Chemical Vendors|Curation Efforts|Governmental...
#
#                                           annotation
# 0  D002491 - Central Nervous System Agents > D018...
# 1                                                NaN
# 2  C308 - Immunotherapeutic Agent > C2139 - Immun...
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 40 columns]
# <ipython-input-8-38c7b0240361>:2: DtypeWarning: Columns (32,35,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114288 entries, 0 to 114287
# Data columns (total 40 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0    cid                    114288 non-null  int64
#  1   cmpdname                114288 non-null  object
#  2   cmpdsynonym             112994 non-null  object
#  3   mw                      114288 non-null  float64
#  4   mf                      114288 non-null  object
#  5   polararea               114288 non-null  float64
#  6   complexity              114288 non-null  float64
#  7   xlogp                   106200 non-null  float64
#  8   heavycnt                114288 non-null  int64
#  9   hbonddonor              114288 non-null  int64
#  10  hbondacc                114288 non-null  int64
#  11  rotbonds                114288 non-null  int64
#  12  inchi                   114288 non-null  object
#  13  isosmiles               114288 non-null  object
#  14  canonicalsmiles         114288 non-null  object
#  15  inchikey                114288 non-null  object
#  16  iupacname               113949 non-null  object
#  17  exactmass               114288 non-null  float64
#  18  monoisotopicmass        114288 non-null  float64
#  19  charge                  114288 non-null  int64
#  20  covalentunitcnt         114288 non-null  int64
#  21  isotopeatomcnt          114288 non-null  int64
#  22  totalatomstereocnt      114288 non-null  int64
#  23  definedatomstereocnt    114288 non-null  int64
#  24  undefinedatomstereocnt  114288 non-null  int64
#  25  totalbondstereocnt      114288 non-null  int64
#  26  definedbondstereocnt    114288 non-null  int64
#  27  undefinedbondstereocnt  114288 non-null  int64
#  28  pclidcnt                114288 non-null  int64
#  29  gpidcnt                 114288 non-null  int64
#  30  gpfamilycnt             114288 non-null  int64
#  31  neighbortype            113948 non-null  object
#  32  meshheadings            7312 non-null    object
#  33  annothits               114237 non-null  object
#  34  annothitcnt             114288 non-null  int64
#  35  aids                    20579 non-null   object
#  36  cidcdate                114288 non-null  int64
#  37  sidsrcname              114288 non-null  object
#  38  depcatg                 114288 non-null  object
#  39  annotation              19693 non-null   object
# dtypes: float64(6), int64(19), object(15)
# memory usage: 34.9+ MB

# %%
# Drop rows with null values
clean_df = df.dropna()
clean_df
# Out:
#               cid                                           cmpdname  \
# 2               6                        1-Chloro-2,4-dinitrobenzene
# 6              15                          17-Hydroxyandrostan-3-one
# 37             86                          3-Hydroxyanthranilic acid
# 60            119                            Gamma-Aminobutyric Acid
# 73            137                                Aminolevulinic Acid
# ...           ...                                                ...
# 110551  138403272  (1S,3R,4R,7R,9R,11R,15S,16R,17R,18S,33R,36R,37...
# 110552  138403275  (1R,3S,5S,7S,8E,12R,14E,16E,18E,20E,22S,24S,25...
# 110735  139593372  5-(methylamino)-2-[[(2R,3S,5S,8R,9R)-3,5,9-tri...
# 110736  139593379  [(1S,2R,3R,4R,5S,6S,7S,8R,9R,13R,16S,17S,18R)-...
# 112670  155970341        Avermectin A1a, 5-O-demethyl-22,23-dihydro-
#
#                                               cmpdsynonym      mw          mf  \
# 2       1-chloro-2,4-dinitrobenzene|2,4-Dinitrochlorob...  202.55  C6H3ClN2O4
# 6       17-Hydroxyandrostan-3-one|Etiocholan-17.beta.-...  290.40    C19H30O2
# 37      2-Amino-3-hydroxybenzoic acid|3-Hydroxyanthran...  153.14     C7H7NO3
# 60      4-aminobutyric acid|4-Aminobutanoic acid|gamma...  103.12     C4H9NO2
# 73      5-Aminolevulinic acid|Aminolevulinic acid|106-...  131.13     C5H9NO3
# ...                                                   ...     ...         ...
# 110551                                           nystatin  926.10  C47H75NO17
# 110552                                          NATAMYCIN  665.70  C33H47NO13
# 110735                                            A-23187  523.60  C29H37N3O6
# 110736                                          aconitine  645.70  C34H47NO11
# 112670  Avermectin A1a, 5-O-demethyl-22,23-dihydro-|IV...  875.10   C48H74O14
#
#         polararea  complexity  xlogp  heavycnt  hbonddonor  ...  gpfamilycnt  \
# 2            91.6       224.0    2.3        13           0  ...         4796
# 6            37.3       459.0    3.7        21           1  ...            8
# 37           83.6       160.0    0.9        11           3  ...          958
# 60           63.3        62.7   -3.2         7           2  ...        18828
# 73           80.4       121.0   -3.8         9           2  ...        11158
# ...           ...         ...    ...       ...         ...  ...          ...
# 110551      320.0      1620.0   -0.2        65          12  ...            0
# 110552      231.0      1220.0   -1.3        47           7  ...            0
# 110735      127.0       873.0    5.9        38           3  ...            0
# 110736      153.0      1210.0    0.3        46           3  ...            0
# 112670      170.0      1680.0    4.1        62           3  ...            0
#
#         neighbortype               meshheadings  \
# 2              2D+3D       Dinitrochlorobenzene
# 6                 2D        Dihydrotestosterone
# 37             2D+3D  3-Hydroxyanthranilic Acid
# 60             2D+3D    gamma-Aminobutyric Acid
# 73             2D+3D        Aminolevulinic Acid
# ...              ...                        ...
# 110551            2D                   Nystatin
# 110552            2D                  Natamycin
# 110735            2D                 Calcimycin
# 110736         2D+3D                  Aconitine
# 112670            2D                 Ivermectin
#
#                                                 annothits annothitcnt  \
# 2       Biological Test Results|Chemical and Physical ...          14
# 6       Biological Test Results|Classification|Literat...           7
# 37      Biological Test Results|Chemical and Physical ...          14
# 60      Biological Test Results|Chemical and Physical ...          15
# 73      Biological Test Results|Chemical and Physical ...          13
# ...                                                   ...         ...
# 110551  Biological Test Results|Chemical and Physical ...          12
# 110552  Biological Test Results|Chemical and Physical ...          11
# 110735  Biological Test Results|Classification|Literat...           4
# 110736  Biological Test Results|Classification|Drug an...           7
# 112670  Biological Test Results|Chemical and Physical ...          12
#
#                                                      aids  cidcdate  \
# 2       155|157|161|165|167|175|179|192|220|300|302|11...  20050326
# 6                                 1259397|1259398|1259423  20050325
# 37      155|157|161|165|167|175|1376|1385|1422|1465|15...  20040916
# 60      155|157|161|165|167|175|190|248|328|357|410|41...  20040916
# 73      1511|1554|1662|1663|1672|1813|1814|1832|1850|1...  20040916
# ...                                                   ...       ...
# 110551                    1347061|1347062|1347063|1347066  20190622
# 110552                    1347061|1347062|1347063|1347066  20190622
# 110735                                            1347148  20191118
# 110736                                            1347148  20191118
# 112670                                            1671498  20210720
#
#                                                sidsrcname  \
# 2       3B Scientific (Wuhan) Corp|3WAY PHARM INC|A&J ...
# 6       A2B Chem|AA BLOCKS|ABI Chem|AKos Consulting & ...
# 37      001Chemical|3B Scientific (Wuhan) Corp|3WAY PH...
# 60      001Chemical|3B Scientific (Wuhan) Corp|3WAY PH...
# 73      001Chemical|3B Scientific (Wuhan) Corp|3WAY PH...
# ...                                                   ...
# 110551                                     NIH/NCATS RNAi
# 110552                                     NIH/NCATS RNAi
# 110735             WashU High Throughput Screening Center
# 110736    WashU High Throughput Screening Center|Wikidata
# 112670  A2B Chem|AA BLOCKS|Aaron Chemicals LLC|ChEMBL|...
#
#                                                   depcatg  \
# 2       Chemical Vendors|Curation Efforts|Governmental...
# 6       Chemical Vendors|Curation Efforts|Governmental...
# 37      Chemical Vendors|Curation Efforts|Governmental...
# 60      Chemical Vendors|Curation Efforts|Governmental...
# 73      Chemical Vendors|Curation Efforts|Governmental...
# ...                                                   ...
# 110551                                    NIH Initiatives
# 110552                                    NIH Initiatives
# 110735         Legacy Depositors|Research and Development
# 110736  Curation Efforts|Legacy Depositors|Research an...
# 112670  Chemical Vendors|Curation Efforts|Research and...
#
#                                                annotation
# 2       C308 - Immunotherapeutic Agent > C2139 - Immun...
# 6       D006730 - Hormones, Hormone Substitutes, and H...
# 37      D000975 - Antioxidants > D016166 - Free Radica...
# 60      D018377 - Neurotransmitter Agents > D018682 - ...
# 73      C1420 - Photosensitizing Agent|D003879 - Derma...
# ...                                                   ...
# 110551  A - Alimentary tract and metabolism > A07 - An...
# 110552  A - Alimentary tract and metabolism > A01 - St...
# 110735  D000890 - Anti-Infective Agents > D000900 - An...
# 110736  D007155 - Immunologic Factors|D049990 - Membra...
# 112670  D - Dermatologicals|D000890 - Anti-Infective A...
#
# [2972 rows x 40 columns]

# %%
#check the info of non-null values
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2972 entries, 2 to 112670
# Data columns (total 40 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0    cid                    2972 non-null   int64
#  1   cmpdname                2972 non-null   object
#  2   cmpdsynonym             2972 non-null   object
#  3   mw                      2972 non-null   float64
#  4   mf                      2972 non-null   object
#  5   polararea               2972 non-null   float64
#  6   complexity              2972 non-null   float64
#  7   xlogp                   2972 non-null   float64
#  8   heavycnt                2972 non-null   int64
#  9   hbonddonor              2972 non-null   int64
#  10  hbondacc                2972 non-null   int64
#  11  rotbonds                2972 non-null   int64
#  12  inchi                   2972 non-null   object
#  13  isosmiles               2972 non-null   object
#  14  canonicalsmiles         2972 non-null   object
#  15  inchikey                2972 non-null   object
#  16  iupacname               2972 non-null   object
#  17  exactmass               2972 non-null   float64
#  18  monoisotopicmass        2972 non-null   float64
#  19  charge                  2972 non-null   int64
#  20  covalentunitcnt         2972 non-null   int64
#  21  isotopeatomcnt          2972 non-null   int64
#  22  totalatomstereocnt      2972 non-null   int64
#  23  definedatomstereocnt    2972 non-null   int64
#  24  undefinedatomstereocnt  2972 non-null   int64
#  25  totalbondstereocnt      2972 non-null   int64
#  26  definedbondstereocnt    2972 non-null   int64
#  27  undefinedbondstereocnt  2972 non-null   int64
#  28  pclidcnt                2972 non-null   int64
#  29  gpidcnt                 2972 non-null   int64
#  30  gpfamilycnt             2972 non-null   int64
#  31  neighbortype            2972 non-null   object
#  32  meshheadings            2972 non-null   object
#  33  annothits               2972 non-null   object
#  34  annothitcnt             2972 non-null   int64
#  35  aids                    2972 non-null   object
#  36  cidcdate                2972 non-null   int64
#  37  sidsrcname              2972 non-null   object
#  38  depcatg                 2972 non-null   object
#  39  annotation              2972 non-null   object
# dtypes: float64(6), int64(19), object(15)
# memory usage: 952.0+ KB

# %%
# Select random 1000 rows
sample_data = clean_df.sample(n=1000)

# %%
# Filter the DataFrame to include only three desired columns
filter_df = sample_data[['isosmiles', 'canonicalsmiles', 'mw']]
filter_df
# Out:
#                                                isosmiles  \
# 1388                CCCCC(CC)CN1CC(CN(C1)CC(CC)CCCC)(C)N
# 1381   C1=C(C(=C(C(=C1Cl)Cl)CC2=C(C(=CC(=C2Cl)Cl)Cl)O...
# 18499         C([C@H]([C@H]([C@@H]([C@@H](CBr)O)O)O)O)Br
# 21718  CC(C)C[C@@H](C(=O)N[C@@H](CCCN=C(N)N)C(=O)N1CC...
# 2192    CC1=NN=C2N1C3=C(C=C(C=C3)Cl)C(=NC2)C4=CC=CC=C4Cl
# ...                                                  ...
# 21577  C[C@@H]1CC[C@H]2C[C@@H](/C(=C/C=C/C=C/[C@H](C[...
# 3660         CCCCC(CC)COC(=O)C1=CC=CC=C1C(=O)OCC(CC)CCCC
# 45918    CN1C(=C(C2=CC=CC=C2S1(=O)=O)O)C(=O)NC3=CC=CC=N3
# 5662   C[C@@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@@]4([C@...
# 2319                               C1=C(C(=O)NC(=O)N1)Br
#
#                                          canonicalsmiles       mw
# 1388                CCCCC(CC)CN1CC(CN(C1)CC(CC)CCCC)(C)N   339.60
# 1381   C1=C(C(=C(C(=C1Cl)Cl)CC2=C(C(=CC(=C2Cl)Cl)Cl)O...   406.90
# 18499                           C(C(C(C(C(CBr)O)O)O)O)Br   307.96
# 21718  CC(C)CC(C(=O)NC(CCCN=C(N)N)C(=O)N1CCCC1C(=O)NN...  1269.40
# 2192    CC1=NN=C2N1C3=C(C=C(C=C3)Cl)C(=NC2)C4=CC=CC=C4Cl   343.20
# ...                                                  ...      ...
# 21577  CC1CCC2CC(C(=CC=CC=CC(CC(C(=O)C(C(C(=CC(C(=O)C...   914.20
# 3660         CCCCC(CC)COC(=O)C1=CC=CC=C1C(=O)OCC(CC)CCCC   390.60
# 45918    CN1C(=C(C2=CC=CC=C2S1(=O)=O)O)C(=O)NC3=CC=CC=N3   331.30
# 5662   CC1CC2C3CCC4=CC(=O)C=CC4(C3(C(CC2(C1(C(=O)COC(...   497.60
# 2319                               C1=C(C(=O)NC(=O)N1)Br   190.98
#
# [1000 rows x 3 columns]

# %%
# Rename the 'mw' column to 'molecularweight'
filter_df.rename(columns={'mw': 'molecularweight'}, inplace=True)
# Out:
# <ipython-input-14-bb53d368d4ee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df.rename(columns={'mw': 'molecularweight'}, inplace=True)

# %%
filter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1388 to 2319
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   isosmiles        1000 non-null   object
#  1   canonicalsmiles  1000 non-null   object
#  2   molecularweight  1000 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 31.2+ KB

# %%
# Defining the folder name
folder_name = "Ersilia"

# Defining the file name
file_name = "cleaned_dataset.csv"

# Defining the full path to the file
output_file_path = f"/content/drive/MyDrive/Ersilia/cleaned_dataset.csv"

# Save the cleaned DataFrame to a CSV file
filter_df.to_csv(output_file_path, index=False)

# %%
# To confirm that the file has been saved
print("Cleaned dataset saved to:", output_file_path)
# Out:
# Cleaned dataset saved to: /content/drive/MyDrive/Ersilia/cleaned_dataset.csv
