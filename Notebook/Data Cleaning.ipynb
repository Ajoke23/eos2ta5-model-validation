# %%
#import necessary libraries
import pandas as pd
import os

# %%
# Mount Google Drive to access files if necessary
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define the folder name and file name
folder_name = "Ersilia"
file_name = "PubChem Data.csv"

# Define the full path to the file
file_path = os.path.join("/content/drive/MyDrive", folder_name, file_name)

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the first 5 rows in DataFrame
print(df.head())
# Out:
#     cid         cmpdname                                        cmpdsynonym  \
# 0   206           Hexose  Hexopyranose|hexopyranoside|Hexose|6-(hydroxym...
# 1   312     Chloride Ion  16887-00-6|chloride|chloride ion|Chloride anio...
# 2   588       creatinine  60-27-5|AYI8EX34EU|creatinine|2-Imino-1-methyl...
# 3   767    Carbonic Acid  463-79-6|carbonic acid|H2CO3|Koehlensaeure|hyd...
# 4   769  Bicarbonate Ion  71-52-3|Bicarbonate (HCO3-)|Bicarbonate ion|Bi...
#
#         mw       mf  polararea  complexity  xlogp  heavycnt  hbonddonor  ...  \
# 0  180.160  C6H12O6      110.0       151.0   -2.6        12           5  ...
# 1   35.450      Cl-        0.0         0.0    0.8         1           0  ...
# 2  113.120  C4H7N3O       58.7       151.0   -1.8         8           1  ...
# 3   62.025    CH2O3       57.5        26.3   -0.1         4           2  ...
# 4   61.017    CHO3-       60.4        24.8    0.5         4           1  ...
#
#    gpfamilycnt  neighbortype   meshheadings  \
# 0         5525         2D+3D            NaN
# 1       126524            2D      Chlorides
# 2        15110         2D+3D     Creatinine
# 3        71326         2D+3D  Carbonic Acid
# 4        24345         2D+3D   Bicarbonates
#
#                                            annothits annothitcnt  \
# 0  Biological Test Results|Chemical and Physical ...          12
# 1  Biological Test Results|Chemical and Physical ...          13
# 2  Biological Test Results|Chemical and Physical ...          13
# 3  Biological Test Results|Chemical and Physical ...          13
# 4  Biological Test Results|Classification|Drug an...          10
#
#                                                 aids  cidcdate  \
# 0  155|157|161|165|167|175|192|248|256|328|880|88...  20050325
# 1  1794832|1798763|1803254|1803484|1803485|180348...  20040916
# 2  155|157|161|165|167|175|180|218|248|270|328|33...  20040916
# 3  238317|238327|238328|238410|238411|238440|2384...  20040916
# 4  1798763|1803254|1803484|1803485|1803486|180348...  20040916
#
#                                           sidsrcname  \
# 0  001Chemical|3WAY PHARM INC|A2B Chem|AA BLOCKS|...
# 1  3WAY PHARM INC|abcr GmbH|ABI Chem|Acorn Pharma...
# 2  001Chemical|1st Scientific|3B Scientific (Wuha...
# 3  001Chemical|1st Scientific|3B Scientific (Wuha...
# 4  ABI Chem|Alfa Chemistry|AN PharmaTech|BIND|Bin...
#
#                                              depcatg  \
# 0  Chemical Vendors|Curation Efforts|Governmental...
# 1  Chemical Vendors|Curation Efforts|Governmental...
# 2  Chemical Vendors|Curation Efforts|Governmental...
# 3  Chemical Vendors|Curation Efforts|Governmental...
# 4  Chemical Vendors|Curation Efforts|Governmental...
#
#                                           annotation
# 0                                                NaN
# 1                                                NaN
# 2  COVID-19|COVID19|Coronavirus|Corona-virus|SARS...
# 3                                                NaN
# 4  D019995 - Laboratory Chemicals > D002021 - Buf...
#
# [5 rows x 40 columns]

# %% [markdown]
# Converting the canonicalsmile columns to standardize SMILES

# %%
pip install rdkit
# Out:
# Collecting rdkit
#   Downloading rdkit-2023.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.25.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (9.4.0)
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.9.5

# %%
from rdkit import Chem

# function to convert SMILES to standardized SMILES
def convert_to_standardized_smiles(smiles):
    """
    Convert a SMILES string to standardized SMILES notation.

    Args:
        smiles (str): The SMILES string to convert.

    Returns:
        str: The standardized SMILES notation.
    """
    try:
        mol = Chem.MolFromSmiles(smiles)
        standardized_smiles = Chem.MolToSmiles(mol)
        return standardized_smiles
    except Exception as e:
        print(f"Error converting SMILES '{smiles}' to standardized SMILES: {e}")
        return None

# Apply the function to the 'canonicalsmiles' column of the DataFrame
df['standardized_smiles'] = df['canonicalsmiles'].apply(convert_to_standardized_smiles)

# Print the DataFrame to verify the results
print(df)
# Out:
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] Explicit valence for atom # 3 Si, 8, is greater than permitted
# [06:43:13] Explicit valence for atom # 1 Si, 8, is greater than permitted
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] Explicit valence for atom # 1 Si, 8, is greater than permitted
# Error converting SMILES '[NH4+].[NH4+].F[Si-2](F)(F)(F)(F)F' to standardized SMILES: Python argument types in
#     rdkit.Chem.rdmolfiles.MolToSmiles(NoneType)
# did not match C++ signature:
#     MolToSmiles(RDKit::ROMol mol, bool isomericSmiles=True, bool kekuleSmiles=False, int rootedAtAtom=-1, bool canonical=True, bool allBondsExplicit=False, bool allHsExplicit=False, bool doRandom=False)
#     MolToSmiles(RDKit::ROMol mol, RDKit::SmilesWriteParams params)
# Error converting SMILES 'F[Si-2](F)(F)(F)(F)F.[Na+].[Na+]' to standardized SMILES: Python argument types in
#     rdkit.Chem.rdmolfiles.MolToSmiles(NoneType)
# did not match C++ signature:
#     MolToSmiles(RDKit::ROMol mol, bool isomericSmiles=True, bool kekuleSmiles=False, int rootedAtAtom=-1, bool canonical=True, bool allBondsExplicit=False, bool allHsExplicit=False, bool doRandom=False)
#     MolToSmiles(RDKit::ROMol mol, RDKit::SmilesWriteParams params)
# Error converting SMILES 'F[Si-2](F)(F)(F)(F)F.[Ca+2]' to standardized SMILES: Python argument types in
#     rdkit.Chem.rdmolfiles.MolToSmiles(NoneType)
# did not match C++ signature:
#     MolToSmiles(RDKit::ROMol mol, bool isomericSmiles=True, bool kekuleSmiles=False, int rootedAtAtom=-1, bool canonical=True, bool allBondsExplicit=False, bool allHsExplicit=False, bool doRandom=False)
#     MolToSmiles(RDKit::ROMol mol, RDKit::SmilesWriteParams params)
#             cid                                           cmpdname  \
# 0           206                                             Hexose
# 1           312                                       Chloride Ion
# 2           588                                         creatinine
# 3           767                                      Carbonic Acid
# 4           769                                    Bicarbonate Ion
# ...         ...                                                ...
# 2259   21924740                         Potassium;hydron;phosphate
# 2260   21924748                          Disodium;hydron;phosphate
# 2261   58592228                                       CID 58592228
# 2262   90657278  (2S)-2-azaniumyl-3-[hydroxy(nitroso)amino]prop...
# 2263  129632725                                      CID 129632725
#
#                                             cmpdsynonym       mw        mf  \
# 0     Hexopyranose|hexopyranoside|Hexose|6-(hydroxym...  180.160   C6H12O6
# 1     16887-00-6|chloride|chloride ion|Chloride anio...   35.450       Cl-
# 2     60-27-5|AYI8EX34EU|creatinine|2-Imino-1-methyl...  113.120   C4H7N3O
# 3     463-79-6|carbonic acid|H2CO3|Koehlensaeure|hyd...   62.025     CH2O3
# 4     71-52-3|Bicarbonate (HCO3-)|Bicarbonate ion|Bi...   61.017     CHO3-
# ...                                                 ...      ...       ...
# 2259                                                NaN  136.086    H2KO4P
# 2260                                                NaN  141.959   HNa2O4P
# 2261                                                NaN  141.959   HNa2O4P
# 2262                                                NaN  149.110  C3H7N3O4
# 2263                                                NaN  189.670  C3H2O4Sr
#
#       polararea  complexity  xlogp  heavycnt  hbonddonor  ...  neighbortype  \
# 0         110.0     151.000   -2.6        12           5  ...         2D+3D
# 1           0.0       0.000    0.8         1           0  ...            2D
# 2          58.7     151.000   -1.8         8           1  ...         2D+3D
# 3          57.5      26.300   -0.1         4           2  ...         2D+3D
# 4          60.4      24.800    0.5         4           1  ...         2D+3D
# ...         ...         ...    ...       ...         ...  ...           ...
# 2259       86.2      36.800    NaN         6           2  ...            2D
# 2260       86.2      36.800    NaN         7           1  ...            2D
# 2261       83.4      64.099    NaN         7           1  ...            2D
# 2262      121.0     132.000   -3.2        10           2  ...         2D+3D
# 2263       80.3      87.500    NaN         8           0  ...            2D
#
#        meshheadings                                          annothits  \
# 0               NaN  Biological Test Results|Chemical and Physical ...
# 1         Chlorides  Biological Test Results|Chemical and Physical ...
# 2        Creatinine  Biological Test Results|Chemical and Physical ...
# 3     Carbonic Acid  Biological Test Results|Chemical and Physical ...
# 4      Bicarbonates  Biological Test Results|Classification|Drug an...
# ...             ...                                                ...
# 2259            NaN                                            Patents
# 2260            NaN                                            Patents
# 2261            NaN                                            Patents
# 2262            NaN                                 Literature|Patents
# 2263            NaN                                 Literature|Patents
#
#      annothitcnt                                               aids  cidcdate  \
# 0             12  155|157|161|165|167|175|192|248|256|328|880|88...  20050325
# 1             13  1794832|1798763|1803254|1803484|1803485|180348...  20040916
# 2             13  155|157|161|165|167|175|180|218|248|270|328|33...  20040916
# 3             13  238317|238327|238328|238410|238411|238440|2384...  20040916
# 4             10  1798763|1803254|1803484|1803485|1803486|180348...  20040916
# ...          ...                                                ...       ...
# 2259           2                                                NaN  20071205
# 2260           2                                                NaN  20071205
# 2261           2                                                NaN  20120819
# 2262           4                                                NaN  20150306
# 2263           2                                                NaN  20170913
#
#                                              sidsrcname  \
# 0     001Chemical|3WAY PHARM INC|A2B Chem|AA BLOCKS|...
# 1     3WAY PHARM INC|abcr GmbH|ABI Chem|Acorn Pharma...
# 2     001Chemical|1st Scientific|3B Scientific (Wuha...
# 3     001Chemical|1st Scientific|3B Scientific (Wuha...
# 4     ABI Chem|Alfa Chemistry|AN PharmaTech|BIND|Bin...
# ...                                                 ...
# 2259   Collaborative Drug Discovery, Inc.|DiscoveryGate
# 2260   Collaborative Drug Discovery, Inc.|DiscoveryGate
# 2261                                            SCRIPDB
# 2262                                             BioCyc
# 2263                 PATENTSCOPE (WIPO)|Springer Nature
#
#                                                 depcatg  \
# 0     Chemical Vendors|Curation Efforts|Governmental...
# 1     Chemical Vendors|Curation Efforts|Governmental...
# 2     Chemical Vendors|Curation Efforts|Governmental...
# 3     Chemical Vendors|Curation Efforts|Governmental...
# 4     Chemical Vendors|Curation Efforts|Governmental...
# ...                                                 ...
# 2259            Legacy Depositors|Subscription Services
# 2260            Legacy Depositors|Subscription Services
# 2261         Legacy Depositors|Research and Development
# 2262             Curation Efforts|Subscription Services
# 2263      Governmental Organizations|Journal Publishers
#
#                                              annotation  \
# 0                                                   NaN
# 1                                                   NaN
# 2     COVID-19|COVID19|Coronavirus|Corona-virus|SARS...
# 3                                                   NaN
# 4     D019995 - Laboratory Chemicals > D002021 - Buf...
# ...                                                 ...
# 2259                                                NaN
# 2260                                                NaN
# 2261                                                NaN
# 2262                                                NaN
# 2263                                                NaN
#
#                        standardized_smiles
# 0                     OCC1OC(O)C(O)C(O)C1O
# 1                                    [Cl-]
# 2                           CN1CC(=O)N=C1N
# 3                                  O=C(O)O
# 4                               O=C([O-])O
# ...                                    ...
# 2259    O=P([O-])([O-])[O-].[H+].[H+].[K+]
# 2260  O=P([O-])([O-])[O-].[H+].[Na+].[Na+]
# 2261          O=P([O-])([O-])O.[Na+].[Na+]
# 2262            [NH3+]C(CN(O)N=O)C(=O)[O-]
# 2263            O=C([O-])CC(=O)[O-].[Sr+2]
#
# [2264 rows x 41 columns]
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors
# [06:43:13] WARNING: not removing hydrogen atom without neighbors

# %%
# Rename the 'standardized_smiles' column to 'smiles'
df = df.rename(columns={'standardized_smiles': 'smiles'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2264 entries, 0 to 2263
# Data columns (total 41 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0    cid                    2264 non-null   int64
#  1   cmpdname                2264 non-null   object
#  2   cmpdsynonym             2253 non-null   object
#  3   mw                      2264 non-null   float64
#  4   mf                      2264 non-null   object
#  5   polararea               2264 non-null   float64
#  6   complexity              2264 non-null   float64
#  7   xlogp                   1547 non-null   float64
#  8   heavycnt                2264 non-null   int64
#  9   hbonddonor              2264 non-null   int64
#  10  hbondacc                2264 non-null   int64
#  11  rotbonds                2264 non-null   int64
#  12  inchi                   2264 non-null   object
#  13  isosmiles               2264 non-null   object
#  14  canonicalsmiles         2264 non-null   object
#  15  inchikey                2264 non-null   object
#  16  iupacname               2223 non-null   object
#  17  exactmass               2264 non-null   float64
#  18  monoisotopicmass        2264 non-null   float64
#  19  charge                  2264 non-null   int64
#  20  covalentunitcnt         2264 non-null   int64
#  21  isotopeatomcnt          2264 non-null   int64
#  22  totalatomstereocnt      2264 non-null   int64
#  23  definedatomstereocnt    2264 non-null   int64
#  24  undefinedatomstereocnt  2264 non-null   int64
#  25  totalbondstereocnt      2264 non-null   int64
#  26  definedbondstereocnt    2264 non-null   int64
#  27  undefinedbondstereocnt  2264 non-null   int64
#  28  pclidcnt                2264 non-null   int64
#  29  gpidcnt                 2264 non-null   int64
#  30  gpfamilycnt             2264 non-null   int64
#  31  neighbortype            2244 non-null   object
#  32  meshheadings            733 non-null    object
#  33  annothits               2264 non-null   object
#  34  annothitcnt             2264 non-null   int64
#  35  aids                    1568 non-null   object
#  36  cidcdate                2264 non-null   int64
#  37  sidsrcname              2264 non-null   object
#  38  depcatg                 2264 non-null   object
#  39  annotation              1001 non-null   object
#  40  smiles                  2261 non-null   object
# dtypes: float64(6), int64(19), object(16)
# memory usage: 725.3+ KB

# %%
# Select random 1000 rows
sample_data = df.sample(n=1000)

# %%
# Filter the DataFrame to include only three desired columns
filter_df = sample_data[['canonicalsmiles', 'smiles','inchikey', 'mw']]
filter_df
# Out:
#               canonicalsmiles                smiles  \
# 533                    CN(C)C                CN(C)C
# 521     C1CCC(CC1)NS(=O)(=O)O   O=S(=O)(O)NC1CCCCC1
# 1206  CC(C1=CC(=CC=C1)O)N(C)C  CC(c1cccc(O)c1)N(C)C
# 1729      C(C(CS(=O)(=O)O)S)S     O=S(=O)(O)CC(S)CS
# 1249         CC(C)CC(C(=O)O)O      CC(C)CC(O)C(=O)O
# ...                       ...                   ...
# 374         C1=CC=C(C(=C1)O)O            Oc1ccccc1O
# 1762       C[N+](C)(C)CC(=O)O    C[N+](C)(C)CC(=O)O
# 1799         C[Se]CC(C(=O)O)N      C[Se]CC(N)C(=O)O
# 1779     CC(=O)O.CC(=O)O.[Zn]  CC(=O)O.CC(=O)O.[Zn]
# 1334                      CON                   CON
#
#                          inchikey       mw
# 533   GETQZCLCWQTVFV-UHFFFAOYSA-N   59.110
# 521   HCAJEUSONLESMK-UHFFFAOYSA-N  179.240
# 1206  GQZXRLWUYONVCP-QMMMGPOBSA-N  165.230
# 1729  JLVSRWOIZZXQAD-UHFFFAOYSA-N  188.300
# 1249  LVRFTAZAXQPQHI-YFKPBYRVSA-N  132.160
# ...                           ...      ...
# 374   YCIMNLLNPGFGHC-UHFFFAOYSA-N  110.110
# 1762  KWIUHFFTVRNATP-UHFFFAOYSA-O  118.150
# 1799  XDSSPSLGNGIIHP-UHFFFAOYSA-N  182.090
# 1779  ZOIORXHNWRGPMV-UHFFFAOYSA-N  185.500
# 1334  GMPKIPWJBDOURN-UHFFFAOYSA-N   47.057
#
# [1000 rows x 4 columns]

# %%
# Rename the 'mw' column to 'molecularweight'
filter_df.rename(columns={'mw': 'molecularweight'}, inplace=True)
# Out:
# <ipython-input-11-bb53d368d4ee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df.rename(columns={'mw': 'molecularweight'}, inplace=True)

# %%
filter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 533 to 1334
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   canonicalsmiles  1000 non-null   object
#  1   smiles           999 non-null    object
#  2   inchikey         1000 non-null   object
#  3   molecularweight  1000 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 39.1+ KB

# %%
# Defining the folder name
folder_name = "Ersilia"

# Defining the file name
file_name = "clean_data.csv"

# Defining the full path to the file
output_file_path = f"/content/drive/MyDrive/Ersilia/clean_data.csv"

# Save the cleaned DataFrame to a CSV file
filter_df.to_csv(output_file_path, index=False)

# %%
# To confirm that the file has been saved
print("Cleaned dataset saved to:", output_file_path)
# Out:
# Cleaned dataset saved to: /content/drive/MyDrive/Ersilia/clean_data.csv
